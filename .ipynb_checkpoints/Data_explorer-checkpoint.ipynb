# %%
from main import *

# %%
machines = ["M01"] #,"M02","M03"]
#process_names = ["OP00","OP01","OP02","OP03","OP04","OP05","OP06","OP07","OP08","OP09","OP10","OP11","OP12","OP13","OP14"]
process_names = ["OP02"]
labels = ["good","bad"]
path_to_dataset = Path("./data/").absolute()

# %%
X_data = []
y_data = []

for process_name, machine, label in itertools.product(process_names, machines, labels):
    data_path = os.path.join(path_to_dataset, machine, process_name, label)
    data_list, data_label = data_loader_utils.load_tool_research_data(data_path, label=label, add_additional_label = True, verbose = False)
    #concatenating
    X_data.extend(data_list)
    y_data.extend(data_label)

# %%
file = Path("./data/M01/OP02/good/M01_Aug_2019_OP02_000.h5").absolute()
sample = data_loader_utils.datafile_read(file)

# %%
from statsmodels.tsa.stattools import grangercausalitytests

sample = X_data[0] # sample is one single example of length 93184 with three dimensions
xy = np.stack((sample[:, 0], sample[:, 1]), axis = 1)
xz = np.stack((sample[:, 0], sample[:, 2]), axis = 1)
yz = np.stack((sample[:, 1], sample[:, 2]), axis = 1)
# Out:
# Granger Causality
# number of lags (no zero) 4500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       5 xz = np.stack((sample[:, 0], sample[:, 2]), axis = 1)
#       6 yz = np.stack((sample[:, 1], sample[:, 2]), axis = 1)
# ----> 8 grangercausalitytests(xy, [4500])
#
# File ~/tf/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:1593, in grangercausalitytests(x, maxlag, addconst, verbose)
#    1590 mxlg = mlg
#    1592 # create lagmat of both time series
# -> 1593 dta = lagmat2ds(x, mxlg, trim="both", dropex=1)
#    1595 # add constant
#    1596 if addconst:
#
# File ~/tf/lib/python3.10/site-packages/statsmodels/tsa/tsatools.py:524, in lagmat2ds(x, maxlag0, maxlagex, dropex, trim, use_pandas)
#     520 elif is_pandas:
#     521     x = np.asanyarray(x)
#     523 lagsli = [
# --> 524     lagmat(x[:, 0], maxlag, trim=trim, original="in")[:, : maxlag0 + 1]
#     525 ]
#     526 for k in range(1, nvar):
#     527     lagsli.append(
#     528         lagmat(x[:, k], maxlag, trim=trim, original="in")[
#     529             :, dropex : maxlagex + 1
#     530         ]
#     531     )
#
# File ~/tf/lib/python3.10/site-packages/statsmodels/tsa/tsatools.py:400, in lagmat(x, maxlag, trim, original, use_pandas)
#     398 lm = np.zeros((nobs + maxlag, nvar * (maxlag + 1)))
#     399 for k in range(0, int(maxlag + 1)):
# --> 400     lm[
#     401     maxlag - k: nobs + maxlag - k,
#     402     nvar * (maxlag - k): nvar * (maxlag - k + 1),
#     403     ] = x
#     405 if trim in ("none", "forward"):
#     406     startobs = 0
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(1,3, figsize = (20,5), sharex = True, sharey = True)
ax[0].hist(sample[:,0])
ax[0].set_title("X-axis histogram")
ax[1].hist(sample[:,1])
ax[1].set_title("Y-axis histogram")
ax[2].hist(sample[:,2])
ax[2].set_title("Z-axis histogram")
ax[0].set_ylabel("Value counts")
# Out:
# Text(0, 0.5, 'Value counts')

# %%
import statsmodels.api as sm
import scipy.stats as stats

fig = sm.qqplot(sample[:,0], stats.logistic, fit = True, line= "s", distargs=(4,))
plt.show()

# %%
from statsmodels.tsa.stattools import acf

acf(sample[:, 0])
# Out:
# array([1.        , 0.91150582, 0.92244745, 0.89968476, 0.92955403,
#        0.9045565 , 0.90031045, 0.87088728, 0.85472938, 0.8536447 ,
#        0.87244192, 0.83681683, 0.80738745, 0.79678021, 0.79953058,
#        0.79379726, 0.78242771, 0.75339866, 0.74538787, 0.73831166,
#        0.76473748, 0.72742739, 0.71475641, 0.69547516, 0.70637581,
#        0.69785506, 0.69133383, 0.66549674, 0.65546235, 0.64854746,
#        0.66363181, 0.63265647, 0.61443337, 0.59480394, 0.59513057,
#        0.58459811, 0.5730199 , 0.54492614, 0.53175934, 0.52158016,
#        0.53264872, 0.49987713, 0.48322769, 0.4632176 , 0.46558205,
#        0.45139074, 0.44381927, 0.41860873, 0.40809275, 0.3997515 ])
